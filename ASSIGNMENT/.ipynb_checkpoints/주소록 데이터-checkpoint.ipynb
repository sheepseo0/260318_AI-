# %%
# 주소록 데이터
import json

addressbook = { 
    "양서영" : "01074432538", 
    "민다영" : "01022532236"
} #딕셔너리 변수로 정보 저장

#1. 파일로 저장 
with open("addressbook.json", "w", encoding = "utf-8") as f: #하드디스크에 방을 하나 만들어서
    json.dump(addressbook, f, ensure_ascii = False, indent = 4) #파일에다가 저 정보를 저장한다.

print("주소록이 저장되었습니다.")

#2. 파일에서 다시 불러오기
with open("addressbook.json", "r", encoding = "utf-8") as f: 
    loaded_addressbook = json.load(f) 

print("불러온 주소록:", loaded_addressbook) 
print("양서영 번호:", loaded_addressbook["양서영"])

# %%
# 주소록 데이터
import json

addressbook = { 
    "양서영" : "01074432538", 
    "민다영" : "01022532236"
} #딕셔너리 변수로 정보 저장

#1. 파일로 저장 
with open("addressbook.json", "w", encoding = "utf-8") as f: #하드디스크에 방을 하나 만들어서
    json.dump(addressbook, f, ensure_ascii = False, indent = 4) #파일에다가 저 정보를 저장한다.

print("주소록이 저장되었습니다.")

'''
#2. 파일에서 다시 불러오기
with open("addressbook.json", "r", encoding = "utf-8") as f: 
    loaded_addressbook = json.load(f) 

print("불러온 주소록:", loaded_addressbook) 
print("양서영 번호:", loaded_addressbook["양서영"])
'''
# Out:
# 주소록이 저장되었습니다.
# '\n#2. 파일에서 다시 불러오기\nwith open("addressbook.json", "r", encoding = "utf-8") as f: \n    loaded_addressbook = json.load(f) \n\nprint("불러온 주소록:", loaded_addressbook) \nprint("양서영 번호:", loaded_addressbook["양서영"])\n'

# %%
import json

'''
# 주소록 데이터
addressbook = { 
    "양서영" : "01074432538", 
    "민다영" : "01022532236"
} #딕셔너리 변수로 정보 저장

#1. 파일로 저장 
with open("addressbook.json", "w", encoding = "utf-8") as f: #하드디스크에 방을 하나 만들어서
    json.dump(addressbook, f, ensure_ascii = False, indent = 4) #파일에다가 저 정보를 저장한다.

print("주소록이 저장되었습니다.")
'''

#2. 파일에서 다시 불러오기
with open("addressbook.json", "r", encoding = "utf-8") as f: 
    addressbook = json.load(f) 

print("불러온 주소록:", addressbook) 
print("양서영 번호:", addressbook["양서영"])


#이렇게 하는 게 무슨 의미가 있는건데 다른 걸 어디서 어떻게 확인할 수 있는건데
#암튼 이렇게 하고 이제 추가시킬거임!
# Out:
# 불러온 주소록: {'양서영': '01074432538', '민다영': '01022532236'}
# 양서영 번호: 01074432538

# %%
#주소록 입력 받을 겁니다~
import json

# 주소록 데이터
addressbook = { 
    "양서영" : "01074432538", 
    "민다영" : "01022532236"
} #딕셔너리 변수로 정보 저장

name = None
while(name != "끝"):
    name = input("이름을 입력하세요:")
    if(name == "끝"): 
        break
    phonenum = input("전화번호를 입력하세요:")
    
    addressbook[name] = phonenum

#1. 파일로 저장 
with open("addressbook.json", "w", encoding = "utf-8") as f: #하드디스크에 방을 하나 만들어서
    json.dump(addressbook, f, ensure_ascii = False, indent = 4) #파일에다가 저 정보를 저장한다.

print("주소록이 저장되었습니다.")


#2. 파일에서 다시 불러오기
with open("addressbook.json", "r", encoding = "utf-8") as f: 
    addressbook = json.load(f) 

print("불러온 주소록:", addressbook) 
print("양서영 번호:", addressbook["양서영"])

#여기서 기능을 확장하라고??? 어떻게????? 
#이렇게 되면 기존에 만들었던 코드를 유지를 못한대. 파일이 다 날라가..
# Out:
# 이름을 입력하세요: 끝
# 주소록이 저장되었습니다.
# 불러온 주소록: {'양서영': '01074432538', '민다영': '01022532236'}
# 양서영 번호: 01074432538
