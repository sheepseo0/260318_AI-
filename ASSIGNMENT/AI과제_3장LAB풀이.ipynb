# %%
#3-6

for i in range(5):
    print("Hello, Python")
# Out:
# Hello, Python
# Hello, Python
# Hello, Python
# Hello, Python
# Hello, Python

# %%
n = 7
for i in range(n):
    st = ''
    for j in range(i):
        st = st+' '
    print(st+'*')
# Out:
# *
#  *
#   *
#    *
#     *
#      *
#       *

# %%
n = 7
for i in range(n):
    print(' '*i + '#')
# Out:
# #
#  #
#   #
#    #
#     #
#      #
#       #

# %%
n = 7
for i in range(n):
    print(' '*(n-i-1) + '#')
# Out:
#       #
#      #
#     #
#    #
#   #
#  #
# #
