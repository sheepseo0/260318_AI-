# %%
num = 100 #num에 특정 값을 주고 
print('num =', num) #출력함
num = 200
print('num =', num)
num = 300
print('num =', num)
# Out:
# num = 100
# num = 200

# %%
num = 0
for i in range(3): #제어문
    num += 100
    print('num =',num)
# Out:
# num = 100
# num = 200
# num = 300

# %%
num = 0
for i in range(3): #제어문
    num += 100
    print('ith num =', i, num)
# Out:
# ith num = 0 100
# ith num = 1 200
# ith num = 2 300

# %%
#조건문
age = int(input("나이를 입력하시오"))
if age < 20:
    print("청소년 할인")
elif age >= 65: 
    print("경로우대")
else:
    print("d")
# Out:
#   Cell In[17], line 7
#     else:
#          ^
# _IncompleteInputError: incomplete input
