# %%
import datetime
detetime.datetime.now() 

#이렇게 하면 지금 시간 표시됨
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import datetime
# ----> 2 detetime.datetime.now()
#
# NameError: name 'detetime' is not defined

# %%
import datetime as dt #이렇게 짧게 할 수 있음
dt.datetime.now()
# Out:
# datetime.datetime(2026, 4, 10, 11, 25, 29, 352190)

# %%
#남은 시간 구하기
import datetime as dt
today = dt.date.today()
print("오늘은 {}년 {}월 {}일입니다.".format(today.year, today.month, today.day))
xMas = dt.datetime(2026, 12, 25)
time_gap = xMas - dt.datetime.now()
print("다음 크리스마스까지는 {}일 {}시간 남았습니다.".format(time_gap.days, time_gap.seconds//360))
# Out:
# 오늘은 2026년 4월 10일입니다.
# 다음 크리스마스까지는 258일 124시간 남았습니다.
