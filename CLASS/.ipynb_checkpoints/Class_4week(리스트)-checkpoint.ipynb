# %%
score = [40,60,70,80,90,85]
name = ['다영', '다연', '서영', '채연', '영호', score] #리스트 안에 리스트 넣을 수 있다!
addressbook = [['다영', '22', '010-9433-9393'], ['다연', '22', '010-9438-6593']]
for i in addressbook: 
    print(score[0:6:2]) #0, 2, 4자리에 있는 리스트 뽑아냄
# Out:
# [40, 70, 90]
# [40, 70, 90]

# %%
ri = list(range(9)) #list 변수로 변환하는 것
print(ri)
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
myString = 'apple'

for ch in myString:
    print(ch)

liststring = list(myString)
print(liststring)
# Out:
# a
# p
# p
# l
# e
# ['a', 'p', 'p', 'l', 'e']

# %%
a = ['a','b','c','d','e']
a.append('f') #append() 메소드 : 이미 존재하는 리스트 끝에 새로운 항목 삽입하기
a
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
a = [10,20,30,40]
a.append(50) #50 추가
a
# Out:
# [10, 20, 30, 40, 50]

# %%
n_list = [1,2,3,4,5]
a = n_list.pop() #제일 뒤에 걸 빼고 리스트에서 삭제시킴
print(a)
print(n_list)
# Out:
# 5
# [1, 2, 3, 4]

# %%
n_list = [1,2,3,4,5]
10 not in n_list
# Out:
# True

# %%
list1 = [25,124,67,98,22]
list1.sort() #정리하는 거
list1
# Out:
# [22, 25, 67, 98, 124]

# %%
list1 = [20,10,40,50,60]
list2 = sorted(list1)
print(list1)
print(list2)
# Out:
# [20, 10, 40, 50, 60]
# [10, 20, 40, 50, 60]

# %%
list1=[1,2,3,4]
list2=[1,2,4,3]
print(list1<list2)
# Out:
# True
