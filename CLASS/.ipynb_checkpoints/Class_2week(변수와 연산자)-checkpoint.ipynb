# %%
#비트
#변수 설명

x = 100
y = 100
char =  'my first code'
print(type(char)) #type() : 값의 데이터 타입(자료형)이 무엇인지 알려주는. 이 값이 숫자인지 문자열인지 리스트인지 확인하는 함수
# Out:
# <class 'str'>

# %%
print(char)
# Out:
# my first code

# %%
#면적과 둘레 구하기
radius = input("반지름을 입력하세요:")
area = 3.14*radius**2
circle = 2.0*3.14*radius
print("면적:", area, "둘레:", circle)
# Out:
# 반지름을 입력하세요: 3
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 radius = input("반지름을 입력하세요:")
#       3 print(type(radius))
# ----> 4 area = 3.14*radius**2
#       5 circle = 2.0*3.14*radius
#       6 print("면적:", area, "둘레:", circle)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
radius = int(input("반지름을 입력하세요:")) #입력값 받기 #int : 문자열 / float : 소수 숫자
print(type(radius)) 
area = 3.14*radius**2
circle = 2.0*3.14*radius
print("면적:", area, "둘레:", circle)

#<class 'int'> : "radius는 문자열이다"
# Out:
# 반지름을 입력하세요: 3
# <class 'int'>
# 면적: 28.26 둘레: 18.84
